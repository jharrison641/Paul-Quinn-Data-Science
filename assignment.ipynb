# %%
import pandas as pd
#importing Pandas librabry

# %%
data = pd.read_csv('/content/kobe data.csv')
data
#assigng data to kobe data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1881/1803250530.py in <cell line: 0>()
# ----> 1 data = pd.read_csv('/content/kobe data.csv')
#       2 data
#       3 #assigng data to kobe data
#
# ...

# %%
data.describe()

# %%
data["period"]

# %%
data["period"].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data["shot_distance"], data["shot_made_flag"])

# %% [markdown]
# There is 2 distinct groups shot distance and shot made flag

# %%
import plotly.express as px
#df = px.data.iris()

# %%
plt.scatter(data["action_type"], data["shot_type"])

# %%
plt.scatter(data["loc_x"], data["loc_y"])
#taking the date from loc x and loc y and displaying on a graph

# %% [markdown]
# 2 distinct groups bottom area is more condensed than the top area.

# %%
plt.scatter(data["action_type"], data["minutes_remaining"])
#taking the date from action type and minutes remaining and displaying on a graph
# set the title
plt.title("kobe Shot Tracker")
# set the x-axis label
plt.xlabel("Action Type")
# set the y-axis label
plt.ylabel("Minutes Remaining")

# %%
import plotly.express as px
fig = px.scatter(data, x="matchup", y="game_date", color="shot_type",
                 size='shot_zone_basic', hover_data=['team_id'])
fig.show()

# %% [markdown]
# I DID NOT KNOW HOW TO FIX THIS ISSUE I IMPORTED PLOTLY AND ATTACHED DATA TO FIG
